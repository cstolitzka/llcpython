# %%
rawData = open("test_resume.txt").read()

rawData[0:500]
# Out:
# 'An accomplished Product Management team player with extensive and diversified experience in defining and delivering successful consumer and enterprise software products to meet market needs. In-depth knowledge of product-life-cycle management, business development and leading cross-functional teams. Excellent domain knowledge in Mobile and Web applications, Navigation and Location Based services, Software as a Service (SaaS), and Enterprise Security products. A self-starter with proven ability t'

# %%
rawData [:]
# Out:
# "An accomplished Product Management team player with extensive and diversified experience in defining and delivering successful consumer and enterprise software products to meet market needs. In-depth knowledge of product-life-cycle management, business development and leading cross-functional teams. Excellent domain knowledge in Mobile and Web applications, Navigation and Location Based services, Software as a Service (SaaS), and Enterprise Security products. A self-starter with proven ability to manage multiple products and projects.\n\nWork Experience\n\nProduct Manager Good Technology April 2011 to November 2013\n\n• Responsible for roadmap strategy and delivery of Good's flagship product, Good for Enterprise, which provides security and management to application data and devices. It has allowed enterprises and government sectors to manage and deploy a secure collaboration solution to millions of mobile devices.\n• Drive requirements definition, development and platform support o
# ...

# %%
rawData = rawData.replace('\n•','').replace('\n','')
rawData[:]
# Out:
# "An accomplished Product Management team player with extensive and diversified experience in defining and delivering successful consumer and enterprise software products to meet market needs. In-depth knowledge of product-life-cycle management, business development and leading cross-functional teams. Excellent domain knowledge in Mobile and Web applications, Navigation and Location Based services, Software as a Service (SaaS), and Enterprise Security products. A self-starter with proven ability to manage multiple products and projects.Work ExperienceProduct Manager Good Technology April 2011 to November 2013 Responsible for roadmap strategy and delivery of Good's flagship product, Good for Enterprise, which provides security and management to application data and devices. It has allowed enterprises and government sectors to manage and deploy a secure collaboration solution to millions of mobile devices. Drive requirements definition, development and platform support of user-valued fe
# ...

# %%
parsedData = rawData.split(' ')
parsedData[:]
# Out:
# ['An',
#  'accomplished',
#  'Product',
#  'Management',
#  'team',
#  'player',
#  'with',
#  'extensive',
#  'and',
#  'diversified',
#  'experience',
#  'in',
#  'defining',
#  'and',
#  'delivering',
#  'successful',
#  'consumer',
#  'and',
#  'enterprise',
#  'software',
#  'products',
#  'to',
#  'meet',
#  'market',
#  'needs.',
#  'In-depth',
#  'knowledge',
#  'of',
#  'product-life-cycle',
#  'management,',
#  'business',
#  'development',
#  'and',
#  'leading',
#  'cross-functional',
#  'teams.',
#  'Excellent',
#  'domain',
#  'knowledge',
#  'in',
#  'Mobile',
#  'and',
#  'Web',
#  'applications,',
#  'Navigation',
#  'and',
#  'Location',
#  'Based',
#  'services,',
#  'Software',
#  'as',
#  'a',
#  'Service',
#  '(SaaS),',
#  'and',
#  'Enterprise',
#  'Security',
#  'products.',
#  'A',
#  'self-starter',
#  'with',
#  'proven',
#  'ability',
#  'to',
#  'manage',
#  'multiple',
#  'products',
#  'and',
#  'projects.Work',
#  'ExperienceProduct',
#  'Manager',
# ...

# %%
parsedData.sort()
parsedData[:]
# Out:
# ['#1',
#  '#1',
#  '(SaaS),',
#  '-',
#  '1.0',
#  '1997',
#  '1997.',
#  '1999',
#  '1999',
#  '2003',
#  '2004',
#  '2005',
#  '2005',
#  '2007',
#  '2007',
#  '2010',
#  '2010',
#  '2010',
#  '2011',
#  '2013',
#  '4',
#  '5',
#  '5X',
#  '7.5,',
#  '8',
#  '8',
#  '98133',
#  'A',
#  'AT&T',
#  'AT&T,',
#  'Advisory',
#  'Akamai',
#  'Akamai',
#  'Akamai',
#  'Alltel,',
#  'An',
#  'Android',
#  'Android',
#  'Android',
#  'Android',
#  'April',
#  'Based',
#  'Bell',
#  'BlackBerry,',
#  'Board',
#  'Broadcasting',
#  'Business',
#  'Business',
#  'C',
#  'CA',
#  'California',
#  'Canada',
#  'Collaborate',
#  'Computer',
#  'Conceived',
#  'Conduct',
#  'Conduct',
#  'Conduct',
#  'Conference.Product',
#  'Coordinate',
#  'Created',
#  'Created',
#  'Customer',
#  'DB2',
#  'DB2.EducationB.S.',
#  'Define',
#  'Delivered',
#  'Designed',
#  'Designed',
#  'Designed',
#  'Develop',
#  'Develop',
#  'Develop',
#  'Developed',
#  'Developed',
#  'Developed',
#  "Developer's",
# ...

# %%
import nltk

# %%
#for aris in parsedData:
#    if aris.isdigit():
#        aris.getindex()
#        print(aris)
        
for index, item in enumerate(parsedData):
    if aris.isdigit():
        parsedData.pop(index)
        
parsedData[:]
# Out:
# ['#1',
#  '-',
#  '1997',
#  '1999',
#  '2003',
#  '2005',
#  '2007',
#  '2010',
#  '2010',
#  '2013',
#  '5',
#  '7.5,',
#  '8',
#  'A',
#  'AT&T,',
#  'Akamai',
#  'Akamai',
#  'An',
#  'Android',
#  'Android',
#  'Based',
#  'BlackBerry,',
#  'Broadcasting',
#  'Business',
#  'CA',
#  'Canada',
#  'Computer',
#  'Conduct',
#  'Conduct',
#  'Coordinate',
#  'Created',
#  'DB2',
#  'Define',
#  'Designed',
#  'Designed',
#  'Develop',
#  'Developed',
#  'Developed',
#  'Diego,',
#  'Engineer',
#  'Engineering',
#  'Ensure',
#  'Enterprise',
#  'Enterprise,',
#  'Establish',
#  'ExperienceProduct',
#  'February',
#  'FileMaker',
#  'FileMaker',
#  'Flash',
#  'GPS',
#  'Go',
#  'Go.',
#  'Good',
#  "Good's",
#  'HDML',
#  'Host',
#  'ISV,',
#  'Identify',
#  'In-depth',
#  'Inc',
#  'Inc',
#  'Internet',
#  'It',
#  'J2EE',
#  'J2ME',
#  'Java',
#  'July',
#  'July',
#  'Lead',
#  'Led',
#  'Lotus',
#  'MacWorld.',
#  'Manage',
#  'Manager',
#  'Manager',
#  'Marketing',
#  'May',
# ...
